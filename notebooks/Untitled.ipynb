# %%
import pandas as pd

# %%
dfa
# Out:
#                                                      url  \
# 0        https://github.com/pandas-dev/pandas/pull/59308
# 1      https://github.com/pandas-dev/pandas/issues/59307
# 2        https://github.com/pandas-dev/pandas/pull/59306
# 3        https://github.com/pandas-dev/pandas/pull/59305
# 4        https://github.com/pandas-dev/pandas/pull/59304
# ...                                                  ...
# 59252      https://github.com/pandas-dev/pandas/issues/5
# 59253      https://github.com/pandas-dev/pandas/issues/4
# 59254      https://github.com/pandas-dev/pandas/issues/3
# 59255      https://github.com/pandas-dev/pandas/issues/2
# 59256      https://github.com/pandas-dev/pandas/issues/1
#
#                                        repository_url          id  \
# 0      https://api.github.com/repos/pandas-dev/pandas  2428648354
# 1      https://api.github.com/repos/pandas-dev/pandas  2428583885
# 2      https://api.github.com/repos/pandas-dev/pandas  2428535262
# ...
